# %%
pip install SpeechRecognition pyttsx3
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
#     --------------------------------------- 0.5/32.9 MB 670.4 kB/s eta 0:00:49
# ...

# %%
import speech_recognition as sr

# %%
import pyttsx3

# %%
engine = pyttsx3.init()

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def recognize_speech():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening for a command...")
        audio = recognizer.listen(source)
        
        try:
            print("Recognizing speech...")
            command = recognizer.recognize_google(audio, language='ar-EG')  # Arabic (Egypt)
            print("Recognized command: ", command)
            return command.lower()
        except sr.UnknownValueError:
            print("Speech was not understood.")
            return None
        except sr.RequestError:
            print("Could not connect to Google API.")
            return None

# %%
def execute_command(command):
    if command:
        if 'ابدأ' in command:
            speak("Patrol started.")
        elif 'توقف' in command:
            speak("Patrol stopped.")
        elif 'افحص المنطقة' in command:
            speak("Scanning the area.")
        else:
            speak("Sorry, I did not understand the command.")
    else:
        speak("No command recognized.")

# %%
# !pip install PyAudio

# %%
import speech_recognition as sr

def recognize_speech():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Calibrating for background noise...")
        recognizer.adjust_for_ambient_noise(source, duration=1)
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        command = recognizer.recognize_google(audio, language="en-US")  # English only
        return command
    except sr.UnknownValueError:
        return "Sorry, I didn't catch that."
    except sr.RequestError:
        return "Error: Could not connect to the speech recognition service."

if __name__ == "__main__":
    while True:
        command = recognize_speech()
        print(f"You said: {command}")
# Out:
# Calibrating for background noise...
# Listening...
# You said: Sorry, I didn't catch that.
# Calibrating for background noise...
# Listening...
# You said: what time is it
# Calibrating for background noise...
# Listening...
# You said: Sorry, I didn't catch that.
# Calibrating for background noise...
# Listening...
# You said: what time is
# Calibrating for background noise...
# Listening...
# You said: open Google
# Calibrating for background noise...
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 21
#      19 if __name__ == "__main__":
#      20     while True:
# ---> 21         command = recognize_speech()
#      22         print(f"You said: {command}")
#
# Cell In[3], line 9, in recognize_speech()
#       7     recognizer.adjust_for_ambient_noise(source, duration=1)
#       8     print("Listening...")
# ...
